# %%
import sys
sys.path.append('../')

# %load_ext autoreload
# %autoreload 0
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from omegaconf import OmegaConf, DictConfig
from rdkit import Chem
from rdkit.Chem import AllChem

cfg = OmegaConf.load("../configs/default.yaml")
type(cfg)
# Out:
# omegaconf.dictconfig.DictConfig

# %%
import warnings
from Bio.PDB import PDBParser
from Bio.PDB.Model import Model
from Bio.PDB.PDBExceptions import PDBConstructionWarning

# %%
parser = PDBParser()
rec_file = "/home/boris/Data/BigBindNew/ODPB_HUMAN_31_359_0/3exf_B_rec_pocket.pdb"
with warnings.catch_warnings():
    warnings.filterwarnings("ignore", category=PDBConstructionWarning)
    structure = parser.get_structure('random_id', rec_file)
    rec = structure[0]

# %%
from datasets.graphs.prot_graph import ProtGraph
cfg.data.rec_graph.node_type = "residue"
graph = ProtGraph(cfg, rec)
print(graph.edata.scal_feat[0])
i, j = graph.edges[0]
print(graph.ndata[i].coord, graph.ndata[j].coord)
# Out:
# tensor([11.4909])
# tensor([-86.7120,   8.6030,   7.6380]) tensor([-77.1690,  14.7480,   9.4300])

# %%
from datasets.graphs.plot_graph import plot_graph
plot_graph(graph)
